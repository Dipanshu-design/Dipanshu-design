# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
pd.set_option('display.max_columns',None)

# %%
data=pd.read_csv('C:\\Users\\garg9\\OneDrive\\Desktop\\data science\\machine learning\\Supervised\\linear regression\\project 2\\Fish_dataset.csv')
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# # Bar chart showing count of individual species

# %%
data['Species'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
sns.boxplot(data['Weight'])
plt.subplot(3,2,2)
sns.boxplot(data['Length1'])
plt.subplot(3,2,3)
sns.boxplot(data['Length2'])
plt.subplot(3,2,4)
sns.boxplot(data['Length3'])
plt.subplot(3,2,5)
sns.boxplot(data['Height'])
plt.subplot(3,2,6)
sns.boxplot(data['Width'])
plt.show()

# %%
data1=data.iloc[ : ,1:]
data1
# Out:
#      Weight  Length1  Length2  Length3   Height   Width
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
Q1 = np.quantile(data['Weight'],0.25)
Q3 = np.quantile(data['Weight'],0.75)
IQR = Q3 - Q1
below=Q1 - 1.5*IQR 
above=Q3 + 1.5*IQR
data_new=data[(data.Weight>below) & (data.Weight<above)]

# %%
data_new
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [156 rows x 7 columns]

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
sns.boxplot(data_new['Weight'])
plt.subplot(3,2,2)
sns.boxplot(data_new['Length1'])
plt.subplot(3,2,3)
sns.boxplot(data_new['Length2'])
plt.subplot(3,2,4)
sns.boxplot(data_new['Length3'])
plt.subplot(3,2,5)
sns.boxplot(data['Height'])
plt.subplot(3,2,6)
sns.boxplot(data['Width'])
plt.show()

# %%
Q1 = np.quantile(data_new['Length1'],0.25)
Q3 = np.quantile(data_new['Length1'],0.75)
IQR = Q3 - Q1
below=Q1 - 1.5*IQR 
above=Q3 + 1.5*IQR
data_new=data_new[(data_new.Length1>below) & (data_new.Length1<above)]
data_new
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [155 rows x 7 columns]

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
sns.boxplot(data_new['Weight'])
plt.subplot(3,2,2)
sns.boxplot(data_new['Length1'])
plt.subplot(3,2,3)
sns.boxplot(data_new['Length2'])
plt.subplot(3,2,4)
sns.boxplot(data_new['Length3'])
plt.subplot(3,2,5)
sns.boxplot(data['Height'])
plt.subplot(3,2,6)
sns.boxplot(data['Width'])
plt.show()

# %%
sns.pairplot(data_new)

# %%
data_new.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.890173  0.894415  0.902576  0.815237  0.925664
# Length1  0.890173  1.000000  0.999385  0.990205  0.688050  0.891260
# Length2  0.894415  0.999385  1.000000  0.992765  0.704041  0.897855
# Length3  0.902576  0.990205  0.992765  1.000000  0.768038  0.898315
# Height   0.815237  0.688050  0.704041  0.768038  1.000000  0.803268
# Width    0.925664  0.891260  0.897855  0.898315  0.803268  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_new.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data_new=data_new.drop(['Length2','Length3'],axis=1)

# %%
data_new=data_new.drop(['Species'],axis=1)

# %%
data_new
# Out:
#      Weight  Length1   Height   Width
# 0     242.0     23.2  11.5200  4.0200
# 1     290.0     24.0  12.4800  4.3056
# 2     340.0     23.9  12.3778  4.6961
# 3     363.0     26.3  12.7300  4.4555
# 4     430.0     26.5  12.4440  5.1340
# ..      ...      ...      ...     ...
# 154    12.2     11.5   2.0904  1.3936
# 155    13.4     11.7   2.4300  1.2690
# 156    12.2     12.1   2.2770  1.2558
# 157    19.7     13.2   2.8728  2.0672
# 158    19.9     13.8   2.9322  1.8792
#
# [155 rows x 4 columns]

# %%
sns.distplot(data_new)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import scipy.stats as st
st.norm.interval(alpha = 0.95, loc = np.mean(data_new.Weight), scale = st.sem(data_new.Weight))
# Out:
# (320.3480851282036, 418.79901164598994)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
data_new=scaler.fit_transform(data_new)

# %%
data_new=pd.DataFrame(data_new)

# %%
data_new
# Out:
#             0         1         2         3
# 0    0.220000  0.384804  0.568334  0.418978
# 1    0.263636  0.404412  0.624055  0.459235
# 2    0.309091  0.401961  0.618123  0.514279
# 3    0.330000  0.460784  0.638566  0.480365
# 4    0.390909  0.465686  0.621966  0.576004
# ..        ...       ...       ...       ...
# 150  0.011091  0.098039  0.021012  0.048771
# 151  0.012182  0.102941  0.040723  0.031208
# 152  0.011091  0.112745  0.031842  0.029347
# 153  0.017909  0.139706  0.066424  0.143719
# 154  0.018091  0.154412  0.069872  0.117219
#
# [155 rows x 4 columns]

# %%
sns.distplot(data_new)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()

# %%
x=data_new.drop(0,axis=1)
x
# Out:
#             1         2         3
# 0    0.384804  0.568334  0.418978
# 1    0.404412  0.624055  0.459235
# 2    0.401961  0.618123  0.514279
# 3    0.460784  0.638566  0.480365
# 4    0.465686  0.621966  0.576004
# ..        ...       ...       ...
# 150  0.098039  0.021012  0.048771
# 151  0.102941  0.040723  0.031208
# 152  0.112745  0.031842  0.029347
# 153  0.139706  0.066424  0.143719
# 154  0.154412  0.069872  0.117219
#
# [155 rows x 3 columns]

# %%
y=data_new[0]
y
# Out:
# 0      0.220000
# 1      0.263636
# 2      0.309091
# 3      0.330000
# 4      0.390909
#          ...
# 150    0.011091
# 151    0.012182
# 152    0.011091
# 153    0.017909
# 154    0.018091
# Name: 0, Length: 155, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=123)

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test)
y_pred
# Out:
# array([ 0.71694736,  0.08465961,  0.44162374,  0.59925702,  0.2711036 ,
#         0.20741398,  0.15035094,  0.15499761, -0.18726115, -0.00733013,
#         0.17787136,  0.46551226,  0.62773996, -0.14979505,  0.08857866,
#         0.35254314,  0.77858251,  0.2686673 ,  0.50224467,  0.1869939 ,
#         0.72446379,  0.71086484,  0.30642897,  0.37707606,  0.37297675,
#         0.35474537,  0.57545857,  0.09318301,  0.66244243,  0.17369884,
#         0.07200617, -0.14092404,  0.77150325,  0.45205365,  0.55706109,
#         0.2135795 ,  0.72850371,  0.1671076 ,  0.32147807])

# %%
linreg.coef_
# Out:
# array([0.46237717, 0.24161223, 0.51086901])

# %%
linreg.intercept_
# Out:
# -0.2078059891191072

# %% [markdown]
# # EQUATION

# %% [markdown]
# Weight=(0.46237717 * Length1)+(0.24161223 * Height)+(0.51086901 * Width)-0.2078059891191072

# %%
rmse=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
rmse
# Out:
# 0.10158242475835531

# %%
y_pred_train = linreg.predict(x_train)
rmse_train = np.sqrt( metrics.mean_squared_error( y_train, y_pred_train) )
rmse_train
# Out:
# 0.08791334521831894

# %%
metrics.r2_score(y_train,y_pred_train)
# Out:
# 0.899587790276545

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.885477533266556
